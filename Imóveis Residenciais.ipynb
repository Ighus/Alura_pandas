# %% [markdown]
# # Relatório de Análise II

# %% [markdown]
# ## Imóveis Residenciais

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel.csv' , sep=';')

# %%
dados
# Out:
#               Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                    Centro        1      0       0    15
# 1      Apartamento              Higienópolis        1      0       0    48
# 2      Apartamento                  Cachambi        2      0       0    50
# 3      Apartamento                    Grajaú        2      1       0    70
# 4      Apartamento       Lins de Vasconcelos        3      1       1    90
# 5      Apartamento                Copacabana        1      0       1    40
# 6      Apartamento   Freguesia (Jacarepaguá)        3      0       0    54
# 7      Apartamento           Barra da Tijuca        2      1       1    67
# 8      Apartamento                    Tijuca        2      1       0   110
# 9      Apartamento                    Olaria        3      1       0    68
# 10     Apartamento                    Tijuca        2      1       0    78
# ...

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
residencial = ['Apartamento', 'Casa', 'Casa de Condomínio', 'Quitinete']

# %%
residencial
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Quitinete']

# %%
dados.head(20)
# Out:
#            Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0   Apartamento                    Centro        1      0       0    15
# 1   Apartamento              Higienópolis        1      0       0    48
# 2   Apartamento                  Cachambi        2      0       0    50
# 3   Apartamento                    Grajaú        2      1       0    70
# 4   Apartamento       Lins de Vasconcelos        3      1       1    90
# 5   Apartamento                Copacabana        1      0       1    40
# 6   Apartamento   Freguesia (Jacarepaguá)        3      0       0    54
# 7   Apartamento           Barra da Tijuca        2      1       1    67
# 8   Apartamento                    Tijuca        2      1       0   110
# 9   Apartamento                    Olaria        3      1       0    68
# 10  Apartamento                    Tijuca        2      1       0    78
# 11  Apartamento                   Ipanema        3      1       1   125
# ...

# %%
selecao = dados['Tipo'].isin(residencial)
selecao
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#          ...
# 19801    True
# 19802    True
# 19803    True
# 19804    True
# 19805    True
# 19806    True
# 19807    True
# 19808    True
# 19809    True
# 19810    True
# 19811    True
# 19812    True
# 19813    True
# 19814    True
# 19815    True
# 19816    True
# 19817    True
# 19818    True
# 19819    True
# 19820    True
# 19821    True
# 19822    True
# 19823    True
# 19824    True
# 19825    True
# 19826    True
# 19827    True
# 19828    True
# 19829    True
# 19830    True
# ...

# %%
dados_residencial = dados[selecao]

# %%
dados_residencial
# Out:
#               Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                    Centro        1      0       0    15
# 1      Apartamento              Higienópolis        1      0       0    48
# 2      Apartamento                  Cachambi        2      0       0    50
# 3      Apartamento                    Grajaú        2      1       0    70
# 4      Apartamento       Lins de Vasconcelos        3      1       1    90
# 5      Apartamento                Copacabana        1      0       1    40
# 6      Apartamento   Freguesia (Jacarepaguá)        3      0       0    54
# 7      Apartamento           Barra da Tijuca        2      1       1    67
# 8      Apartamento                    Tijuca        2      1       0   110
# 9      Apartamento                    Olaria        3      1       0    68
# 10     Apartamento                    Tijuca        2      1       0    78
# ...

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Quitinete']

# %%
# Comando para verificar o tamanho
dados_residencial.shape[0]
# Out:
# 19598

# %%
dados_residencial.index = range(dados_residencial.shape[0])

# %%
dados_residencial
# Out:
#               Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                    Centro        1      0       0    15
# 1      Apartamento              Higienópolis        1      0       0    48
# 2      Apartamento                  Cachambi        2      0       0    50
# 3      Apartamento                    Grajaú        2      1       0    70
# 4      Apartamento       Lins de Vasconcelos        3      1       1    90
# 5      Apartamento                Copacabana        1      0       1    40
# 6      Apartamento   Freguesia (Jacarepaguá)        3      0       0    54
# 7      Apartamento           Barra da Tijuca        2      1       1    67
# 8      Apartamento                    Tijuca        2      1       0   110
# 9      Apartamento                    Olaria        3      1       0    68
# 10     Apartamento                    Tijuca        2      1       0    78
# ...

# %% [markdown]
# ## Exportando a Base de Dados

# %%
# Esc -> M para criar o titulo

# %%
dados_residencial.to_csv('dados/aluguel_residencial.csv', sep=';')

# %%
dados_residencial_2 = pd.read_csv('dados/aluguel_residencial.csv', sep=';')

# %%
dados_residencial_2
# Out:
#        Unnamed: 0         Tipo                    Bairro  Quartos  Vagas  \
# 0               0  Apartamento                    Centro        1      0
# 1               1  Apartamento              Higienópolis        1      0
# 2               2  Apartamento                  Cachambi        2      0
# 3               3  Apartamento                    Grajaú        2      1
# 4               4  Apartamento       Lins de Vasconcelos        3      1
# 5               5  Apartamento                Copacabana        1      0
# 6               6  Apartamento   Freguesia (Jacarepaguá)        3      0
# 7               7  Apartamento           Barra da Tijuca        2      1
# 8               8  Apartamento                    Tijuca        2      1
# 9               9  Apartamento                    Olaria        3      1
# 10             10  Apartamento                    Tijuca        2      1
# 11             11  Apartamento                   Ipanema        3      1
# ...

# %%
dados_residencial.to_csv('dados/aluguel_residencial.csv', sep=';', index= False)

# %%
dados_residencial_2 = pd.read_csv('dados/aluguel_residencial.csv', sep=';')

# %%
dados_residencial_2
# Out:
#               Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                    Centro        1      0       0    15
# 1      Apartamento              Higienópolis        1      0       0    48
# 2      Apartamento                  Cachambi        2      0       0    50
# 3      Apartamento                    Grajaú        2      1       0    70
# 4      Apartamento       Lins de Vasconcelos        3      1       1    90
# 5      Apartamento                Copacabana        1      0       1    40
# 6      Apartamento   Freguesia (Jacarepaguá)        3      0       0    54
# 7      Apartamento           Barra da Tijuca        2      1       1    67
# 8      Apartamento                    Tijuca        2      1       0   110
# 9      Apartamento                    Olaria        3      1       0    68
# 10     Apartamento                    Tijuca        2      1       0    78
# ...
